# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
import cv2

# %%
img = cv2.imread('../images/invoice-sample.jpg')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
plt.imshow(img)

# %%
# matplotlib --> R G B
# CV2        --> B G R

# %%
fix_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB) # to convert color scheme to another

# %%
plt.imshow(fix_img)

# %%
img_gray = cv2.imread('../images/invoice-sample.jpg', cv2.IMREAD_GRAYSCALE)

# %%
plt.imshow(img_gray, cmap='gray')

# %%
fix_img.shape
# Out:
# (1150, 835, 3)

# %%
# resizing image
new_img = cv2.resize(fix_img, (1000,400))

# %%
plt.imshow(new_img)

# %%
# using ratio:
h_ratio = 0.5
w_ratio = 0.5
new_img2 = cv2.resize(fix_img, (0,0), fix_img, w_ratio, h_ratio)

# %%
fix_img.shape
# Out:
# (1150, 835, 3)

# %%
new_img2.shape # half of fix_img
# Out:
# (575, 418, 3)

# %%
plt.imshow(new_img2)

# %%
# Writing image to storage
cv2.imwrite('../images/new_image.jpg', new_img2)
# Out:
# True
